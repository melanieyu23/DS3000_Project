# %% [markdown]
# # Phase II: Data Curation, Exploratory Analysis and Plotting (5\%)
#
# ### Team Members:
# -
# -
# -
#
#
# ## Part 1:
# (1%) Expresses the central motivation of the project and explains the (at least) two key questions to be explored. Gives a summary of the data processing pipeline so a technical expert can easily follow along.

# %% [markdown]
# ## Problem Motivation
#
# Urban traffic congestion poses a growing challenge, driving the need for sustainable alternatives like bike-sharing programs, which offer an eco-friendly and efficient travel method. Analyzing data from the Bluebikes (Metro Boston) system can uncover valuable insights into how bike usage patterns vary across different times of day, locations, and user demographics. This analysis will focus on understanding peak usage times, identifying high-traffic stations, and exploring how trip duration varies based on user type, time of day, and station locations. Additionally, we aim to predict trip duration through machine learning models, which can optimize bike availability and improve system efficiency. The key questions are as follows:
#
# 1. Are there peaks in bike usage during certain times of the day?
# 2. Which stations have the highest traffic, and how does the distribution of bike usage vary geographically? Can we identify high-demand areas that would benefit from more bikes?
# 3. How does bike trip duration vary by user type (eg. age, gender, membership status)?
# 4. Can we predict the trip duration based on factors such as the time of day, user demographics, and starting/ending stations?
#
# Motivating sources:
# - Northeastern University. "Améera." Northeastern University Landscapes, Northeastern University, https://landscapes.northeastern.edu/ameera/. Accessed 30 Sept. 2024.
# - "Environmental Awareness Month: Go Green with Blue Cross and Bluebikes in September." Blue Bikes Boston, http://blog.bluebikes.com/blog/environmental-awareness-month-go-green-with-blue-cross-and-bluebikes-in-september. Accessed 30 Sept. 2024.
# - Streets Cabinet. "Streets Cabinet Announces Bluebikes Expansion Planning." Boston.gov, 12 Aug. 2024, https://www.boston.gov/news/streets-cabinet-announces-bluebikes-expansion-planning. Accessed 30 Sept. 2024.

# %% [markdown]
# ## Summary of the Data Processing Pipeline
#
# 1. Web scrape to get the raw data
# 2. Clean the data to prepare the data frame for visualization and analysis
# 3. Visualize using plotting libraries, such as Seaborn, Plotly, and Matplotlib
#
# To process the data, we will first acquire the Bluebikes datasets. This involves web scraping to successfully collect the data, cleaning the data, and then saving the datasets as (cleaned) .csv files and importing them into our Jupyter Notebook. The cleaning process consists of removing any invalid values, including NaN, n/a, and 0 when applicable. This step will also involve handling missing or inconsistent values across columns such as start station ID, end station ID, and bikeId, converting the starttime and stoptime columns to DateTime format, and removing unanalyzable records like trips with negative tripduration. Next, we will address our key questions. This includes extracting the hour and day of the week from the start time and calculating the user’s age from their birth year to help us analyze usage patterns more effectively. Seeing that there is data in several files, we will combine them using common identifiers like the start station ID and end station ID. After that, we will perform more data analysis to create basic statistics and visualizations. This will include time series plots showing peaks in bike usage and geographical heatmaps (using imported libraries Seaborn, Matplotlib, and Plotly) displaying station traffic based on the names of the start and end stations. These steps will help us address key questions related to peak usage times, station demand, and trip duration patterns across different user demographics. Finally, the cleaned data will be prepared for machine learning by selecting relevant features for predictive modeling of blue bike trip duration.

# %% [markdown]
# ## Part 2:
# (2\%) Obtains, cleans, and merges all data sources involved in the project.

# %%
# Importing Necessary Libraries
import requests
from bs4 import BeautifulSoup
from zipfile import ZipFile
from io import BytesIO
import pandas as pd
import os
# Out:
# /Users/vitakhan/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Function to clean the dataset
def clean_data(df):
    """ 
    Cleans the dataframe by doing the following:
        - Converting columns to datetime.
        - Handling missing or invalid values.
        - Removing unnecessary columns.
        - Converting categorical values like gender.
        - Removing outliers in tripduration.

    Args: 
        df (pd.DataFrame) : a data frame to clean

    Returns:
        df (pd.DataFrame) : cleaned data frame
    """

    # Removing 'n/a', newline characters, and '\N' from all string columns (we noticed these parts in the raw dataset)
    df.replace({"n/a": pd.NA, "\n": pd.NA, r"\N": pd.NA}, inplace=True)

    # Converting 'starttime' and 'stoptime' to datetime format
    df['starttime'] = pd.to_datetime(df['starttime'], errors='coerce')
    df['stoptime'] = pd.to_datetime(df['stoptime'], errors='coerce')

    # Converting tripduration from seconds to minutes (if needed)
    if df['tripduration'].max() > 10000:  # Assume it's in seconds if large
        df['tripduration'] = df['tripduration'] / 60  # Convert to minutes

    # Removing invalid or zero trip durations
    df = df[df['tripduration'] > 0]

    # Removing rows with missing data in specific important columns
    df.dropna(subset=['starttime', 'stoptime', 'start station id', 'end station id', 'bikeid', 'usertype'], inplace=True)

    # Removing any rows with 'n/a' or missing values in other relevant columns, including 'birth year'
    df.dropna(inplace=True)

    # Converting gender (0 = Unknown, 1 = Male, 2 = Female)
    if 'gender' in df.columns:
        df['gender'] = df['gender'].map({0: 'Unknown', 1: 'Male', 2: 'Female'})

    # Removing unrealistic trip durations (ex. over 1000 minutes)
    df = df[df['tripduration'] < 1000]

    return df


# This is the URL of the website hosting the zip files
url = 'https://s3.amazonaws.com/hubway-data'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Initializing a list to hold the links to zip files
zip_links = []
for download_link in soup.find_all('key'):
    # Extracting the 'key' element text
    zip_file_name = download_link.text
    # Appending the URL for zip files to the list if it ends with .zip
    if zip_file_name.endswith('.zip'):
        zip_links.append(f"https://s3.amazonaws.com/hubway-data/{zip_file_name}")

# Creating directory to save CSV files if not exists
if not os.path.exists('csv_files'):
    os.makedirs('csv_files')

# Processing each zip file link and cleaning the data
first_csv_path = None
for i, zip_url in enumerate(zip_links):
    try:
        # Downloading the ZIP file
        zip_response = requests.get(zip_url)
        zip_response.raise_for_status()  # Check for download errors

        # Extracting the ZIP file
        with ZipFile(BytesIO(zip_response.content)) as zip_file:
            for zip_info in zip_file.infolist():
                if zip_info.filename.endswith('.csv'):
                    try:
                        # Extracting the CSV file into a DataFrame
                        with zip_file.open(zip_info) as extracted_file:
                            df = pd.read_csv(extracted_file)
                            print(f"Extracted {zip_info.filename} to DataFrame.")

                            # Cleaning the data using the clean_data function
                            df_cleaned = clean_data(df)

                            # Saving cleaned DataFrame to a CSV file
                            output_filename = f"csv_files/cleaned_{i+1}_{zip_info.filename}"
                            df_cleaned.to_csv(output_filename, index=False)
                            print(f"Saved cleaned {zip_info.filename} to {output_filename}.")

                            if first_csv_path is None:
                                first_csv_path = output_filename
                    except Exception as e:
                        print(f"Error processing {zip_info.filename}: {e}")
                        continue  
    
    except Exception as e:
        print(f"Error downloading or extracting {zip_url}: {e}")
        continue
# Out:
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/html/parser.py:170: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   k = self.parse_starttag(i)
# Extracted 201501-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201501-hubway-tripdata.csv to csv_files/cleaned_1_201501-hubway-tripdata.csv.
# Extracted 201502-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201502-hubway-tripdata.csv to csv_files/cleaned_2_201502-hubway-tripdata.csv.
# Extracted 201503-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201503-hubway-tripdata.csv to csv_files/cleaned_3_201503-hubway-tripdata.csv.
# Extracted 201504-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201504-hubway-tripdata.csv to csv_files/cleaned_4_201504-hubway-tripdata.csv.
# Extracted 201505-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201505-hubway-tripdata.csv to csv_files/cleaned_5_201505-hubway-tripdata.csv.
# Extracted 201506-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201506-hubway-tripdata.csv to csv_files/cleaned_6_201506-hubway-tripdata.csv.
# Extracted 201507-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201507-hubway-tripdata.csv to csv_files/cleaned_7_201507-hubway-tripdata.csv.
# Extracted 201508-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201508-hubway-tripdata.csv to csv_files/cleaned_8_201508-hubway-tripdata.csv.
# Extracted 201509-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201509-hubway-tripdata.csv to csv_files/cleaned_9_201509-hubway-tripdata.csv.
# Extracted 201510-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201510-hubway-tripdata.csv to csv_files/cleaned_10_201510-hubway-tripdata.csv.
# Extracted 201511-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201511-hubway-tripdata.csv to csv_files/cleaned_11_201511-hubway-tripdata.csv.
# Extracted 201512-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201512-hubway-tripdata.csv to csv_files/cleaned_12_201512-hubway-tripdata.csv.
# Extracted 201601-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201601-hubway-tripdata.csv to csv_files/cleaned_13_201601-hubway-tripdata.csv.
# Extracted 201602-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201602-hubway-tripdata.csv to csv_files/cleaned_14_201602-hubway-tripdata.csv.
# Extracted 201603-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201603-hubway-tripdata.csv to csv_files/cleaned_15_201603-hubway-tripdata.csv.
# Extracted 201604-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201604-hubway-tripdata.csv to csv_files/cleaned_16_201604-hubway-tripdata.csv.
# Extracted 201605-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201605-hubway-tripdata.csv to csv_files/cleaned_17_201605-hubway-tripdata.csv.
# Extracted 201606-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201606-hubway-tripdata.csv to csv_files/cleaned_18_201606-hubway-tripdata.csv.
# Extracted 201607-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201607-hubway-tripdata.csv to csv_files/cleaned_19_201607-hubway-tripdata.csv.
# Extracted 201608-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201608-hubway-tripdata.csv to csv_files/cleaned_20_201608-hubway-tripdata.csv.
# Extracted 201609-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201609-hubway-tripdata.csv to csv_files/cleaned_21_201609-hubway-tripdata.csv.
# Extracted 201610-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201610-hubway-tripdata.csv to csv_files/cleaned_22_201610-hubway-tripdata.csv.
# Extracted 201611-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201611-hubway-tripdata.csv to csv_files/cleaned_23_201611-hubway-tripdata.csv.
# Extracted 201612-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201612-hubway-tripdata.csv to csv_files/cleaned_24_201612-hubway-tripdata.csv.
# Extracted 201701-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201701-hubway-tripdata.csv to csv_files/cleaned_25_201701-hubway-tripdata.csv.
# Extracted 201702-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201702-hubway-tripdata.csv to csv_files/cleaned_26_201702-hubway-tripdata.csv.
# Extracted 201703-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201703-hubway-tripdata.csv to csv_files/cleaned_27_201703-hubway-tripdata.csv.
# Extracted 201704-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201704-hubway-tripdata.csv to csv_files/cleaned_28_201704-hubway-tripdata.csv.
# Extracted 201705-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201705-hubway-tripdata.csv to csv_files/cleaned_29_201705-hubway-tripdata.csv.
# Extracted 201706-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201706-hubway-tripdata.csv to csv_files/cleaned_30_201706-hubway-tripdata.csv.
# Extracted 201707-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201707-hubway-tripdata.csv to csv_files/cleaned_31_201707-hubway-tripdata.csv.
# Extracted 201708-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201708-hubway-tripdata.csv to csv_files/cleaned_32_201708-hubway-tripdata.csv.
# Extracted 201709-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201709-hubway-tripdata.csv to csv_files/cleaned_33_201709-hubway-tripdata.csv.
# Extracted 201710-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201710-hubway-tripdata.csv to csv_files/cleaned_34_201710-hubway-tripdata.csv.
# Extracted 201711-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201711-hubway-tripdata.csv to csv_files/cleaned_35_201711-hubway-tripdata.csv.
# Extracted 201712-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201712-hubway-tripdata.csv to csv_files/cleaned_36_201712-hubway-tripdata.csv.
# Extracted 201801_hubway_tripdata.csv to DataFrame.
# Saved cleaned 201801_hubway_tripdata.csv to csv_files/cleaned_37_201801_hubway_tripdata.csv.
# Extracted 201802_hubway_tripdata.csv to DataFrame.
# Saved cleaned 201802_hubway_tripdata.csv to csv_files/cleaned_38_201802_hubway_tripdata.csv.
# Extracted 201803_hubway_tripdata.csv to DataFrame.
# Saved cleaned 201803_hubway_tripdata.csv to csv_files/cleaned_39_201803_hubway_tripdata.csv.
# Extracted 201804-hubway-tripdata.csv to DataFrame.
# Saved cleaned 201804-hubway-tripdata.csv to csv_files/cleaned_40_201804-hubway-tripdata.csv.
# Extracted 201805-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 201805-bluebikes-tripdata.csv to csv_files/cleaned_41_201805-bluebikes-tripdata.csv.
# Extracted 201806-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 201806-bluebikes-tripdata.csv to csv_files/cleaned_42_201806-bluebikes-tripdata.csv.
# Extracted 201807-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 201807-bluebikes-tripdata.csv to csv_files/cleaned_43_201807-bluebikes-tripdata.csv.
# Extracted 201808-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 201808-bluebikes-tripdata.csv to csv_files/cleaned_44_201808-bluebikes-tripdata.csv.
# Extracted 201809-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 201809-bluebikes-tripdata.csv to csv_files/cleaned_45_201809-bluebikes-tripdata.csv.
# Extracted 201810-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 201810-bluebikes-tripdata.csv to csv_files/cleaned_46_201810-bluebikes-tripdata.csv.
# Extracted 201811-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 201811-bluebikes-tripdata.csv to csv_files/cleaned_47_201811-bluebikes-tripdata.csv.
# Extracted 201812-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 201812-bluebikes-tripdata.csv to csv_files/cleaned_48_201812-bluebikes-tripdata.csv.
# Extracted 201901-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 201901-bluebikes-tripdata.csv to csv_files/cleaned_49_201901-bluebikes-tripdata.csv.
# Extracted 201902-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 201902-bluebikes-tripdata.csv to csv_files/cleaned_50_201902-bluebikes-tripdata.csv.
# Extracted 201903-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 201903-bluebikes-tripdata.csv to csv_files/cleaned_51_201903-bluebikes-tripdata.csv.
# Extracted 201904-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 201904-bluebikes-tripdata.csv to csv_files/cleaned_52_201904-bluebikes-tripdata.csv.
# Extracted 201905-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 201905-bluebikes-tripdata.csv to csv_files/cleaned_53_201905-bluebikes-tripdata.csv.
# Extracted 201906-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 201906-bluebikes-tripdata.csv to csv_files/cleaned_54_201906-bluebikes-tripdata.csv.
# Error processing __MACOSX/._201906-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xaa in position 37: invalid start byte
# Extracted 201907-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 201907-bluebikes-tripdata.csv to csv_files/cleaned_55_201907-bluebikes-tripdata.csv.
# Error processing __MACOSX/._201907-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xaa in position 37: invalid start byte
# Extracted 201908-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 201908-bluebikes-tripdata.csv to csv_files/cleaned_56_201908-bluebikes-tripdata.csv.
# Error processing __MACOSX/._201908-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xe2 in position 37: invalid continuation byte
# Extracted 201909-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 201909-bluebikes-tripdata.csv to csv_files/cleaned_57_201909-bluebikes-tripdata.csv.
# Extracted 201910-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 201910-bluebikes-tripdata.csv to csv_files/cleaned_58_201910-bluebikes-tripdata.csv.
# Extracted 201911-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 201911-bluebikes-tripdata.csv to csv_files/cleaned_59_201911-bluebikes-tripdata.csv.
# Extracted 201912-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 201912-bluebikes-tripdata.csv to csv_files/cleaned_60_201912-bluebikes-tripdata.csv.
# Extracted 202001-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202001-bluebikes-tripdata.csv to csv_files/cleaned_61_202001-bluebikes-tripdata.csv.
# Extracted 202002-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202002-bluebikes-tripdata.csv to csv_files/cleaned_62_202002-bluebikes-tripdata.csv.
# Extracted 202003-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202003-bluebikes-tripdata.csv to csv_files/cleaned_63_202003-bluebikes-tripdata.csv.
# Extracted 202004-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202004-bluebikes-tripdata.csv to csv_files/cleaned_64_202004-bluebikes-tripdata.csv.
# Extracted 202005-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202005-bluebikes-tripdata.csv to csv_files/cleaned_65_202005-bluebikes-tripdata.csv.
# Extracted 202006-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202006-bluebikes-tripdata.csv to csv_files/cleaned_66_202006-bluebikes-tripdata.csv.
# Extracted 202007-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202007-bluebikes-tripdata.csv to csv_files/cleaned_67_202007-bluebikes-tripdata.csv.
# Extracted 202008-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202008-bluebikes-tripdata.csv to csv_files/cleaned_68_202008-bluebikes-tripdata.csv.
# Extracted 202009-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202009-bluebikes-tripdata.csv to csv_files/cleaned_69_202009-bluebikes-tripdata.csv.
# Extracted 202010-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202010-bluebikes-tripdata.csv to csv_files/cleaned_70_202010-bluebikes-tripdata.csv.
# Extracted 202011-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202011-bluebikes-tripdata.csv to csv_files/cleaned_71_202011-bluebikes-tripdata.csv.
# Error processing __MACOSX/._202011-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xaa in position 37: invalid start byte
# Extracted 202012-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202012-bluebikes-tripdata.csv to csv_files/cleaned_72_202012-bluebikes-tripdata.csv.
# Error processing __MACOSX/._202012-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xb0 in position 45: invalid start byte
# Extracted 202101-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202101-bluebikes-tripdata.csv to csv_files/cleaned_73_202101-bluebikes-tripdata.csv.
# Extracted 202102-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202102-bluebikes-tripdata.csv to csv_files/cleaned_74_202102-bluebikes-tripdata.csv.
# Extracted 202103-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202103-bluebikes-tripdata.csv to csv_files/cleaned_75_202103-bluebikes-tripdata.csv.
# Extracted 202104-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202104-bluebikes-tripdata.csv to csv_files/cleaned_76_202104-bluebikes-tripdata.csv.
# Error processing __MACOSX/._202104-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xb7 in position 37: invalid start byte
# Extracted 202105-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202105-bluebikes-tripdata.csv to csv_files/cleaned_77_202105-bluebikes-tripdata.csv.
# Extracted 202106-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202106-bluebikes-tripdata.csv to csv_files/cleaned_78_202106-bluebikes-tripdata.csv.
# Extracted 202107-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202107-bluebikes-tripdata.csv to csv_files/cleaned_79_202107-bluebikes-tripdata.csv.
# Extracted 202108-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202108-bluebikes-tripdata.csv to csv_files/cleaned_80_202108-bluebikes-tripdata.csv.
# Error processing __MACOSX/._202108-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xdc in position 99: invalid continuation byte
# Extracted 202109-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202109-bluebikes-tripdata.csv to csv_files/cleaned_81_202109-bluebikes-tripdata.csv.
# Extracted 202110-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202110-bluebikes-tripdata.csv to csv_files/cleaned_82_202110-bluebikes-tripdata.csv.
# Extracted 202111-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202111-bluebikes-tripdata.csv to csv_files/cleaned_83_202111-bluebikes-tripdata.csv.
# Error processing __MACOSX/._202111-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xb7 in position 37: invalid start byte
# Extracted 202112-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202112-bluebikes-tripdata.csv to csv_files/cleaned_84_202112-bluebikes-tripdata.csv.
# Extracted 202201-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202201-bluebikes-tripdata.csv to csv_files/cleaned_85_202201-bluebikes-tripdata.csv.
# Error processing __MACOSX/._202201-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xb7 in position 37: invalid start byte
# Extracted 202202-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202202-bluebikes-tripdata.csv to csv_files/cleaned_86_202202-bluebikes-tripdata.csv.
# Extracted 202203-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202203-bluebikes-tripdata.csv to csv_files/cleaned_87_202203-bluebikes-tripdata.csv.
# Extracted 202204-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202204-bluebikes-tripdata.csv to csv_files/cleaned_88_202204-bluebikes-tripdata.csv.
# Extracted 202205-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202205-bluebikes-tripdata.csv to csv_files/cleaned_89_202205-bluebikes-tripdata.csv.
# Error processing __MACOSX/._202205-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xb7 in position 37: invalid start byte
# Extracted 202206-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202206-bluebikes-tripdata.csv to csv_files/cleaned_90_202206-bluebikes-tripdata.csv.
# Error processing __MACOSX/._202206-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xaa in position 37: invalid start byte
# Extracted 202207-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202207-bluebikes-tripdata.csv to csv_files/cleaned_91_202207-bluebikes-tripdata.csv.
# Error processing __MACOSX/._202207-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xaa in position 37: invalid start byte
# Extracted 202208-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202208-bluebikes-tripdata.csv to csv_files/cleaned_92_202208-bluebikes-tripdata.csv.
# Error processing __MACOSX/._202208-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xdc in position 99: invalid continuation byte
# Extracted 202209-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202209-bluebikes-tripdata.csv to csv_files/cleaned_93_202209-bluebikes-tripdata.csv.
# Error processing __MACOSX/._202209-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xb7 in position 37: invalid start byte
# Extracted 202210-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202210-bluebikes-tripdata.csv to csv_files/cleaned_94_202210-bluebikes-tripdata.csv.
# Error processing __MACOSX/._202210-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xaa in position 37: invalid start byte
# Extracted 202211-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202211-bluebikes-tripdata.csv to csv_files/cleaned_95_202211-bluebikes-tripdata.csv.
# Extracted 202212-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202212-bluebikes-tripdata.csv to csv_files/cleaned_96_202212-bluebikes-tripdata.csv.
# Extracted 202301-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202301-bluebikes-tripdata.csv to csv_files/cleaned_97_202301-bluebikes-tripdata.csv.
# Error processing __MACOSX/._202301-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xb7 in position 37: invalid start byte
# Extracted 202302-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202302-bluebikes-tripdata.csv to csv_files/cleaned_98_202302-bluebikes-tripdata.csv.
# Error processing __MACOSX/._202302-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xdc in position 99: invalid continuation byte
# Extracted 202303-bluebikes-tripdata.csv to DataFrame.
# Saved cleaned 202303-bluebikes-tripdata.csv to csv_files/cleaned_99_202303-bluebikes-tripdata.csv.
# Error processing __MACOSX/._202303-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xaa in position 37: invalid start byte
# Extracted 202304-bluebikes-tripdata.csv to DataFrame.
# Error processing 202304-bluebikes-tripdata.csv: 'starttime'
# Error processing __MACOSX/._202304-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xe4 in position 99: invalid continuation byte
# Extracted 202305-bluebikes-tripdata.csv to DataFrame.
# Error processing 202305-bluebikes-tripdata.csv: 'starttime'
# Error processing __MACOSX/._202305-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xe4 in position 99: invalid continuation byte
# Extracted 202306-bluebikes-tripdata.csv to DataFrame.
# Error processing 202306-bluebikes-tripdata.csv: 'starttime'
# Error processing __MACOSX/._202306-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0x9c in position 37: invalid start byte
# Extracted 202307-bluebikes-tripdata.csv to DataFrame.
# Error processing 202307-bluebikes-tripdata.csv: 'starttime'
# Error processing __MACOSX/._202307-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0x9c in position 37: invalid start byte
# Extracted 202308-bluebikes-tripdata.csv to DataFrame.
# Error processing 202308-bluebikes-tripdata.csv: 'starttime'
# Error processing __MACOSX/._202308-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0x9c in position 37: invalid start byte
# Extracted 202309-bluebikes-tripdata.csv to DataFrame.
# Error processing 202309-bluebikes-tripdata.csv: 'starttime'
# Error processing __MACOSX/._202309-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0x9c in position 37: invalid start byte
# Extracted 202310-bluebikes-tripdata.csv to DataFrame.
# Error processing 202310-bluebikes-tripdata.csv: 'starttime'
# Error processing __MACOSX/._202310-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0x9c in position 37: invalid start byte
# Extracted 202311-bluebikes-tripdata.csv to DataFrame.
# Error processing 202311-bluebikes-tripdata.csv: 'starttime'
# Error processing __MACOSX/._202311-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0x95 in position 45: invalid start byte
# Extracted 202312-bluebikes-tripdata.csv to DataFrame.
# Error processing 202312-bluebikes-tripdata.csv: 'starttime'
# Error processing __MACOSX/._202312-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xe4 in position 99: invalid continuation byte
# Extracted 202401-bluebikes-tripdata.csv to DataFrame.
# Error processing 202401-bluebikes-tripdata.csv: 'starttime'
# Error processing __MACOSX/._202401-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xe4 in position 99: invalid continuation byte
# Extracted 202402-bluebikes-tripdata.csv to DataFrame.
# Error processing 202402-bluebikes-tripdata.csv: 'starttime'
# Error processing __MACOSX/._202402-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xe4 in position 99: invalid continuation byte
# Extracted 202403-bluebikes-tripdata.csv to DataFrame.
# Error processing 202403-bluebikes-tripdata.csv: 'starttime'
# Error processing __MACOSX/._202403-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xe4 in position 99: invalid continuation byte
# Extracted 202404-bluebikes-tripdata.csv to DataFrame.
# Error processing 202404-bluebikes-tripdata.csv: 'starttime'
# Error processing __MACOSX/._202404-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xe4 in position 99: invalid continuation byte
# Extracted 202405-bluebikes-tripdata.csv to DataFrame.
# Error processing 202405-bluebikes-tripdata.csv: 'starttime'
# Error processing __MACOSX/._202405-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xe4 in position 99: invalid continuation byte
# Extracted 202406-bluebikes-tripdata.csv to DataFrame.
# Error processing 202406-bluebikes-tripdata.csv: 'starttime'
# Error processing __MACOSX/._202406-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xe4 in position 99: invalid continuation byte
# Extracted 202407-bluebikes-tripdata.csv to DataFrame.
# Error processing 202407-bluebikes-tripdata.csv: 'starttime'
# Error processing __MACOSX/._202407-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xe4 in position 99: invalid continuation byte
# Extracted 202408-bluebikes-tripdata.csv to DataFrame.
# Error processing 202408-bluebikes-tripdata.csv: 'starttime'
# Error processing __MACOSX/._202408-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xee in position 195: invalid continuation byte
# Extracted 202409-bluebikes-tripdata.csv to DataFrame.
# Error processing 202409-bluebikes-tripdata.csv: 'starttime'
# Error processing __MACOSX/._202409-bluebikes-tripdata.csv: 'utf-8' codec can't decode byte 0xe4 in position 99: invalid continuation byte

# %%
# Test
# Printing first 50 rows of the first cleaned CSV file
if first_csv_path:
    df_first_csv = pd.read_csv(first_csv_path)
    print(df_first_csv.head(50))
else:
    print("No CSV file was extracted and cleaned.")
# Out:
#     tripduration            starttime             stoptime  start station id  \
# 0       9.033333  2015-01-01 00:21:44  2015-01-01 00:30:47               115
# 1       7.300000  2015-01-01 00:27:03  2015-01-01 00:34:21                80
# 2       4.233333  2015-01-01 00:31:31  2015-01-01 00:35:46                91
# 3       7.200000  2015-01-01 00:53:46  2015-01-01 01:00:58               115
# 4      12.250000  2015-01-01 01:07:06  2015-01-01 01:19:21               105
# 5       5.183333  2015-01-01 01:28:27  2015-01-01 01:33:38                88
# 6      20.983333  2015-01-01 01:34:54  2015-01-01 01:55:54                91
# 7       5.633333  2015-01-01 02:32:35  2015-01-01 02:38:13                68
# 8       7.150000  2015-01-01 04:41:58  2015-01-01 04:49:08               117
# 9       4.816667  2015-01-01 08:00:15  2015-01-01 08:05:04                67
# 10      4.600000  2015-01-01 08:22:12  2015-01-01 08:26:48                75
# 11     24.600000  2015-01-01 08:29:05  2015-01-01 08:53:42               115
# 12     18.250000  2015-01-01 08:58:16  2015-01-01 09:16:32                88
# 13      7.433333  2015-01-01 09:15:26  2015-01-01 09:22:52                90
# 14      7.100000  2015-01-01 09:26:21  2015-01-01 09:33:28               116
# 15     21.233333  2015-01-01 10:02:17  2015-01-01 10:23:31                88
# 16      8.983333  2015-01-01 10:27:55  2015-01-01 10:36:54                95
# 17     13.216667  2015-01-01 10:33:31  2015-01-01 10:46:45               116
# 18      7.983333  2015-01-01 10:43:13  2015-01-01 10:51:13               116
# 19      6.083333  2015-01-01 10:48:10  2015-01-01 10:54:15               110
# 20     10.750000  2015-01-01 10:53:36  2015-01-01 11:04:21                90
# 21     11.433333  2015-01-01 10:58:44  2015-01-01 11:10:10                75
# 22      5.516667  2015-01-01 11:27:01  2015-01-01 11:32:33               104
# 23      7.266667  2015-01-01 11:37:53  2015-01-01 11:45:09               140
# 24      6.916667  2015-01-01 11:43:40  2015-01-01 11:50:36               107
# 25      4.600000  2015-01-01 11:49:50  2015-01-01 11:54:26                74
# 26      5.100000  2015-01-01 11:51:00  2015-01-01 11:56:07               107
# 27      4.516667  2015-01-01 11:51:42  2015-01-01 11:56:13               107
# 28      3.883333  2015-01-01 12:21:39  2015-01-01 12:25:32                67
# 29     10.050000  2015-01-01 12:27:30  2015-01-01 12:37:34                68
# 30      8.583333  2015-01-01 12:31:16  2015-01-01 12:39:51                89
# 31      8.400000  2015-01-01 12:35:46  2015-01-01 12:44:10               143
# 32      7.866667  2015-01-01 12:36:15  2015-01-01 12:44:08               143
# 33     13.716667  2015-01-01 12:36:33  2015-01-01 12:50:17                76
# 34      3.150000  2015-01-01 12:40:55  2015-01-01 12:44:04                80
# 35      6.633333  2015-01-01 12:45:35  2015-01-01 12:52:13                68
# 36      3.266667  2015-01-01 12:46:50  2015-01-01 12:50:07                75
# 37     12.683333  2015-01-01 13:03:47  2015-01-01 13:16:28               115
# 38      7.350000  2015-01-01 13:07:47  2015-01-01 13:15:09                88
# 39      8.066667  2015-01-01 13:12:09  2015-01-01 13:20:13               110
# 40     24.216667  2015-01-01 13:12:49  2015-01-01 13:37:02                80
# 41      9.783333  2015-01-01 13:28:41  2015-01-01 13:38:28               141
# 42     20.533333  2015-01-01 13:41:06  2015-01-01 14:01:38               143
# 43     14.833333  2015-01-01 14:06:25  2015-01-01 14:21:15               143
# 44      5.533333  2015-01-01 14:14:19  2015-01-01 14:19:52               140
# 45      6.333333  2015-01-01 14:18:44  2015-01-01 14:25:04                91
# 46     17.333333  2015-01-01 14:23:16  2015-01-01 14:40:37                70
# 47      9.516667  2015-01-01 14:24:36  2015-01-01 14:34:07                76
# 48      6.433333  2015-01-01 14:29:33  2015-01-01 14:35:59                87
# 49     29.800000  2015-01-01 14:41:16  2015-01-01 15:11:04                68
#
#                                    start station name  start station latitude  \
# 0                               Porter Square Station               42.387995
# 1             MIT Stata Center at Vassar St / Main St               42.361962
# 2    One Kendall Square at Hampshire St / Portland St               42.366277
# 3                               Porter Square Station               42.387995
# 4     Lower Cambridgeport at Magazine St/Riverside Rd               42.356954
# 5       Inman Square at Vellucci Plaza / Hampshire St               42.374035
# 6    One Kendall Square at Hampshire St / Portland St               42.366277
# 7               Central Square at Mass Ave / Essex St               42.365070
# 8                                Binney St / Sixth St               42.366095
# 9                        MIT at Mass Ave / Amherst St               42.358100
# 10  Lafayette Square at Mass Ave / Main St / Colum...               42.363465
# 11                              Porter Square Station               42.387995
# 12      Inman Square at Vellucci Plaza / Hampshire St               42.374035
# 13        Lechmere Station at Cambridge St / First St               42.370677
# 14          359 Broadway - Broadway at Fayette Street               42.370803
# 15      Inman Square at Vellucci Plaza / Hampshire St               42.374035
# 16        Cambridge St - at Columbia St / Webster Ave               42.372969
# 17          359 Broadway - Broadway at Fayette Street               42.370803
# 18          359 Broadway - Broadway at Fayette Street               42.370803
# 19  Harvard University Gund Hall at Quincy St / Ki...               42.376369
# 20        Lechmere Station at Cambridge St / First St               42.370677
# 21  Lafayette Square at Mass Ave / Main St / Colum...               42.363465
# 22  Harvard University Radcliffe Quadrangle at She...               42.380287
# 23                                        Danehy Park               42.388966
# 24                                 Ames St at Main St               42.362500
# 25                Harvard Square at Mass Ave/ Dunster               42.373268
# 26                                 Ames St at Main St               42.362500
# 27                                 Ames St at Main St               42.362500
# 28                       MIT at Mass Ave / Amherst St               42.358100
# 29              Central Square at Mass Ave / Essex St               42.365070
# 30         Harvard Law School at Mass Ave / Jarvis St               42.379011
# 31                              EF - North Point Park               42.369885
# 32                              EF - North Point Park               42.369885
# 33  Central Sq Post Office / Cambridge City Hall a...               42.366426
# 34            MIT Stata Center at Vassar St / Main St               42.361962
# 35              Central Square at Mass Ave / Essex St               42.365070
# 36  Lafayette Square at Mass Ave / Main St / Colum...               42.363465
# 37                              Porter Square Station               42.387995
# 38      Inman Square at Vellucci Plaza / Hampshire St               42.374035
# 39  Harvard University Gund Hall at Quincy St / Ki...               42.376369
# 40            MIT Stata Center at Vassar St / Main St               42.361962
# 41                                     Kendall Street               42.363560
# 42                              EF - North Point Park               42.369885
# 43                              EF - North Point Park               42.369885
# 44                                        Danehy Park               42.388966
# 45   One Kendall Square at Hampshire St / Portland St               42.366277
# 46    Harvard Kennedy School at Bennett St / Eliot St               42.371196
# 47  Central Sq Post Office / Cambridge City Hall a...               42.366426
# 48  Harvard University Housing - 115 Putnam Ave at...               42.366621
# 49              Central Square at Mass Ave / Essex St               42.365070
#
#     start station longitude  end station id  \
# 0                -71.119084              96
# 1                -71.092053              95
# 2                -71.091690              68
# 3                -71.119084              96
# 4                -71.113687              88
# 5                -71.101427              76
# 6                -71.091690             118
# 7                -71.103100              95
# 8                -71.086388              76
# 9                -71.093198              75
# 10               -71.100573              67
# 11               -71.119084              36
# 12               -71.101427              23
# 13               -71.076529              80
# 14               -71.104412              80
# 15               -71.101427              46
# 16               -71.094445              80
# 17               -71.104412             115
# 18               -71.104412             141
# 19               -71.114025             104
# 20               -71.076529              88
# 21               -71.100573               6
# 22               -71.125107             110
# 23               -71.132788             115
# 24               -71.088220              68
# 25               -71.118579              87
# 26               -71.088220              91
# 27               -71.088220              91
# 28               -71.093198              68
# 29               -71.103100              68
# 30               -71.119945              95
# 31               -71.069957             117
# 32               -71.069957             117
# 33               -71.105495              74
# 34               -71.092053              75
# 35               -71.103100             107
# 36               -71.100573              80
# 37               -71.119084             116
# 38               -71.101427              80
# 39               -71.114025              70
# 40               -71.092053             143
# 41               -71.082168             116
# 42               -71.069957             143
# 43               -71.069957              72
# 44               -71.132788             115
# 45               -71.091690              84
# 46               -71.121473             105
# 47               -71.105495             107
# 48               -71.114214              68
# 49               -71.103100              84
#
#                                      end station name  end station latitude  \
# 0   Cambridge Main Library at Broadway / Trowbridg...             42.373379
# 1         Cambridge St - at Columbia St / Webster Ave             42.372969
# 2               Central Square at Mass Ave / Essex St             42.365070
# 3   Cambridge Main Library at Broadway / Trowbridg...             42.373379
# 4       Inman Square at Vellucci Plaza / Hampshire St             42.374035
# 5   Central Sq Post Office / Cambridge City Hall a...             42.366426
# 6           Linear Park - Mass. Ave. at Cameron Ave.              42.397828
# 7         Cambridge St - at Columbia St / Webster Ave             42.372969
# 8   Central Sq Post Office / Cambridge City Hall a...             42.366426
# 9   Lafayette Square at Mass Ave / Main St / Colum...             42.363465
# 10                       MIT at Mass Ave / Amherst St             42.358100
# 11           Boston Public Library - 700 Boylston St.             42.349673
# 12                 Mayor Martin J Walsh - 28 State St             42.358920
# 13            MIT Stata Center at Vassar St / Main St             42.361962
# 14            MIT Stata Center at Vassar St / Main St             42.361962
# 15                            Christian Science Plaza             42.343864
# 16            MIT Stata Center at Vassar St / Main St             42.361962
# 17                              Porter Square Station             42.387995
# 18                                     Kendall Street             42.363560
# 19  Harvard University Radcliffe Quadrangle at She...             42.380287
# 20      Inman Square at Vellucci Plaza / Hampshire St             42.374035
# 21                           Cambridge St. at Joy St.             42.361174
# 22  Harvard University Gund Hall at Quincy St / Ki...             42.376369
# 23                              Porter Square Station             42.387995
# 24              Central Square at Mass Ave / Essex St             42.365070
# 25  Harvard University Housing - 115 Putnam Ave at...             42.366621
# 26   One Kendall Square at Hampshire St / Portland St             42.366277
# 27   One Kendall Square at Hampshire St / Portland St             42.366277
# 28              Central Square at Mass Ave / Essex St             42.365070
# 29              Central Square at Mass Ave / Essex St             42.365070
# 30        Cambridge St - at Columbia St / Webster Ave             42.372969
# 31                               Binney St / Sixth St             42.366095
# 32                               Binney St / Sixth St             42.366095
# 33                Harvard Square at Mass Ave/ Dunster             42.373268
# 34  Lafayette Square at Mass Ave / Main St / Colum...             42.363465
# 35                                 Ames St at Main St             42.362500
# 36            MIT Stata Center at Vassar St / Main St             42.361962
# 37          359 Broadway - Broadway at Fayette Street             42.370803
# 38            MIT Stata Center at Vassar St / Main St             42.361962
# 39    Harvard Kennedy School at Bennett St / Eliot St             42.371196
# 40                              EF - North Point Park             42.369885
# 41          359 Broadway - Broadway at Fayette Street             42.370803
# 42                              EF - North Point Park             42.369885
# 43      One Broadway / Kendall Sq at Main St / 3rd St             42.362613
# 44                              Porter Square Station             42.387995
# 45  CambridgeSide Galleria - CambridgeSide PL at L...             42.366981
# 46    Lower Cambridgeport at Magazine St/Riverside Rd             42.356954
# 47                                 Ames St at Main St             42.362500
# 48              Central Square at Mass Ave / Essex St             42.365070
# 49  CambridgeSide Galleria - CambridgeSide PL at L...             42.366981
#
#     end station longitude  bikeid    usertype  birth year  gender
# 0              -71.111075     277  Subscriber        1984    Male
# 1              -71.094445     648  Subscriber        1985    Male
# 2              -71.103100     555  Subscriber        1974    Male
# 3              -71.111075    1307  Subscriber        1987    Male
# 4              -71.101427     177    Customer        1986  Female
# 5              -71.105495     685  Subscriber        1989    Male
# 6              -71.130516     940  Subscriber        1964    Male
# 7              -71.094445     656  Subscriber        1981    Male
# 8              -71.105495     134    Customer        1989    Male
# 9              -71.100573      23  Subscriber        1993    Male
# 10             -71.093198      23  Subscriber        1993    Male
# 11             -71.077303     842  Subscriber        1978    Male
# 12             -71.057629     959  Subscriber        1988  Female
# 13             -71.092053    1306  Subscriber        1988    Male
# 14             -71.092053     854    Customer        1989  Female
# 15             -71.085918     703    Customer        1982    Male
# 16             -71.092053     656  Subscriber        1985  Female
# 17             -71.119084     738  Subscriber        1991    Male
# 18             -71.082168    1113  Subscriber        1984    Male
# 19             -71.125107     549    Customer        1962  Female
# 20             -71.101427     716  Subscriber        1982    Male
# 21             -71.065142     804    Customer        1964    Male
# 22             -71.114025     868    Customer        1962  Female
# 23             -71.119084     742  Subscriber        1987    Male
# 24             -71.103100    1277  Subscriber        1986    Male
# 25             -71.114214     739  Subscriber        1989    Male
# 26             -71.091690     664    Customer        1977    Male
# 27             -71.091690     661    Customer        1986  Female
# 28             -71.103100     442    Customer        1988    Male
# 29             -71.103100     876    Customer        1987  Female
# 30             -71.094445     652    Customer        1970    Male
# 31             -71.086388     646    Customer        1960    Male
# 32             -71.086388     770    Customer        1954    Male
# 33             -71.118579    1265    Customer        1980  Female
# 34             -71.100573    1047  Subscriber        1988    Male
# 35             -71.088220    1277  Subscriber        1986    Male
# 36             -71.092053    1047  Subscriber        1988    Male
# 37             -71.104412     779  Subscriber        1991    Male
# 38             -71.092053    1276  Subscriber        1985    Male
# 39             -71.121473     868  Subscriber        1989  Female
# 40             -71.069957     656  Subscriber        1988    Male
# 41             -71.104412     577  Subscriber        1957  Female
# 42             -71.069957     656  Subscriber        1988    Male
# 43             -71.084105     656  Subscriber        1988    Male
# 44             -71.119084     662    Customer        1990  Female
# 45             -71.076472     642  Subscriber        1985  Female
# 46             -71.113687     725  Subscriber        1989  Female
# 47             -71.088220     134  Subscriber        1986    Male
# 48             -71.103100    1095  Subscriber        1991  Female
# 49             -71.076472     990  Subscriber        1992  Female

# %% [markdown]
# ## Part 3:
# (2\%) Builds at least two visualizations (graphs/plots) from the data which help to understand or answer the questions of interest. These visualizations will be graded based on how much information they can effectively communicate to readers. Please make sure your visualization are sufficiently distinct from each other.

# %%
# importing necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px

# %% [markdown]
# This is a reuse of code from the previous section, but instead of
# saving the data to csv files, instead it compiles the data in a
# dataframe with all of the data. The data must be compiled this way
# because csvs do not preserve object type such as datetime.
# The reason that this is a new code snippet is because compiling the
# full dataframe in the previous snippet would remake all the csvs every time
# the variables were reset.

# %%
# This is the URL of the website hosting the zip files
url = 'https://s3.amazonaws.com/hubway-data'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Initializing a list to hold the links to zip files
zip_links = []
for download_link in soup.find_all('key'):
    # Extracting the 'key' element text
    zip_file_name = download_link.text
    # Appending the URL for zip files to the list if it ends with .zip
    if zip_file_name.endswith('.zip'):
        zip_links.append(f"https://s3.amazonaws.com/hubway-data/{zip_file_name}")

# Initializing the final full dataset to use for the plots
full_dataset = pd.DataFrame()

# Processing each zip file link and cleaning the data
first_csv_path = None
for i, zip_url in enumerate(zip_links):
    try:
        # Downloading the ZIP file
        zip_response = requests.get(zip_url)
        zip_response.raise_for_status()  # Check for download errors

        # Extracting the ZIP file
        with ZipFile(BytesIO(zip_response.content)) as zip_file:
            for zip_info in zip_file.infolist():
                if zip_info.filename.endswith('.csv'):
                    try:
                        # Extracting the CSV file into a DataFrame
                        with zip_file.open(zip_info) as extracted_file:
                            df = pd.read_csv(extracted_file)
                            
                            # Cleaning the data using the clean_data function
                            df_cleaned = clean_data(df)

                            # Combining data into full Dataframe 
                            full_dataset = pd.concat([full_dataset, df_cleaned])
                            
                            if first_csv_path is None:
                                first_csv_path = output_filename
                    except Exception as e:
                        continue  
    
    except Exception as e:
        continue
# Out:
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/html/parser.py:170: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   k = self.parse_starttag(i)

# %%
# plotting with the appropriate data
hist_plot = full_dataset.head(45000)

# setting bin size
bins = np.linspace(0, 50, 40)

# grouping by gender
groups = hist_plot.groupby('gender')

# setting up histogram
plt.style.use('default')
plt.hist([groups.get_group('Male')['tripduration'], groups.get_group('Female')['tripduration']], bins, label=['Male', 'Female'])
plt.legend(loc='upper right')
plt.title('Frequency of Trip Durations by Gender')
plt.xlabel('Duration of Trip (minutes)')
plt.ylabel('Frequency')
plt.show()

# Please see screenshots attached in case Gradescope does not show the plot

# %% [markdown]
# By visualizing this histogram, we can see the frequency distribution of trip durations by gender and answer one of the key questions we had - 'How does bike trip duration vary by user type (eg. gender)?' In our case, we can observe that males tend to take more frequently than females. We can also conclude that the most common trip lengths are roughly between 5 to 8 minutes, and both genders prefer short trips (less than 10 minutes). Moreover, based on the user preferences, long trips (longer than 30 mins) happen rarely.

# %%
# sorting groups by start station name, and creates list of station popularity 
sorted_groups = full_dataset.groupby('start station name')
group_names = sorted_groups.size().sort_values(ascending=False) 

# adding the 12 most popular start stations into the working dataframe
partial = pd.DataFrame()
for i in range(12):
    cur_group = group_names.index[i]
    partial = pd.concat([partial, sorted_groups.get_group(cur_group)])

# sorting groups by end station name, and creates list of station popularity 
sorted_groups = partial.groupby('end station name')
group_names = sorted_groups.size().sort_values(ascending=False) 

# adding the 12 most popular end stations into the working dataframe
partial = pd.DataFrame()
for i in range(12):
    cur_group = group_names.index[i]
    partial = pd.concat([partial, sorted_groups.get_group(cur_group)])

# creating pivot table to initilize heatmap
pivot_df = partial.pivot_table(index='start station name', 
                                    columns='end station name', 
                                    values='tripduration', 
                                    aggfunc='count')

# creating heatmap
sns.heatmap(pivot_df, annot=False, square=True)
plt.title('Most popular start and end station heatmap')
sns.set(font_scale=.8)

# Please see screenshots attached in case Gradescope does not show the plot

# %% [markdown]
# The heatmap shows the most popular start and end stations mapping and answers the question 'Which stations have the highest traffic, and how does the distribution of bike usage vary geographically? Can we identify high-demand areas that would benefit from more bikes?'. We can clearly observe the light beige colors around locations like MIT area, specifically MIT Pacific St at Purrington St and MIT Stata Center at Vassar St/Main St, which indicates the highest traffic and number of trips between stations in that area. On the other hand, we can see low number of trips from South Station. Overall, this heatmap can be helpful when analyzing the distribution of bike usage across stations and also identify high-demand areas, so that the appropriate number of bikes and stations could be installed and supplied in the popular areas.

# %%
# getting the hours from starttime
full_dataset['hour'] = full_dataset['starttime'].dt.hour

# grouping by hour in order to count the number of trips per hour
hourly_trips = full_dataset.groupby('hour').size().reset_index(name='trip_count')

# making a plot
fig = px.line(hourly_trips, x='hour', y='trip_count', title='Number of Bike Trips by Hour of the Day', labels={'hour': 'Hour of Day', 'trip_count': 'Number of Trips'})

# updating the layout to center the title
fig.update_layout(title_x=0.5)
fig.show('iframe')

# Please see screenshots attached in case Gradescope does not show the plot
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_13.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ![LinePlot](plot_screenshots/lineplot.png)

# %% [markdown]
# This line plot shows the trend in the number of bike trips per hour based on the start time of the trip. It highlights the peak of bike usage and answers the question 'Are there peaks in bike usage during certain times of the day?'. We can observe the two peaks, one in the morning at around 8 am, indicating people used bikes to commute to stations or to work, and another one in the evening at 5 pm, meaning people used bikes to commute back to stations or home. Overall, we can see the trend that people tend to use bikes in the evening more than in the morning, with the highest peak at 5 pm.
