# %% [markdown]
# # Phase III: First ML Proof of Concept (5\%)
#
# ### Team Names:
# - Melanie Yu
# - Yunhan Luo
# - Ani McCaskill
# - Owen Sweetman

# %% [markdown]
# ## Part 1: First ML model using Numpy
# (3%) The implementation (using NumPy) of your first ML model as a function call to the cleaned data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("csv_files/cleaned_video_data.csv")
df.head()
# Out:
#       video_id                                              title  \
# 0  9oYHU1hdDog  Agents, AI & The Next Wave: Mike Clark on Vert...
# 1  9EGtawwvlNs                    Build an AI Agent with Gemini 3
# 2  sCXuCczPE8A  What's on the newsdesk for Google Developers t...
# 3  hunRGj4Bpb0         Keep your code fresh and clean with YAGNI!
# 4  L0QHMLx02l4  Introducing ADK Go, User Simulator, and more! ...
#
#               published  views  likes  comments  duration  \
# 0  2025-11-21T00:00:10Z     94      7         2    1602.0
# 1  2025-11-20T21:45:49Z   5454    421        24     383.0
# 2  2025-11-20T20:00:55Z    870     13         1      34.0
# 3  2025-11-20T19:30:53Z    963     20         1      34.0
# 4  2025-11-20T17:02:19Z   2007     87         3     132.0
#
#                                                 tags
# 0  ['Google', 'developers', 'pr_pr: Google Develo...
# 1  ['Google', 'developers', 'pr_pr: AI DevRel (fk...
# 2  ['Google', 'developers', 'pr_pr: Google for De...
# 3  ['Google', 'developers', 'pr_pr: Google for De...
# 4  ['Google', 'developers', 'pr_pr: Google for De...
